# %%
import sFrames
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7fad01691b5a> in <module>()
# ----> 1 import sFrames
#
# ImportError: No module named sFrames

# %%
import graphlabs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ed1d5c525689> in <module>()
# ----> 1 import graphlabs
#
# ImportError: No module named graphlabs

# %% [markdown]
# # Fire up GraphLab Create

# %%
import graphlab
# Out:
# ACTION REQUIRED: Dependencies libstdc++-6.dll and libgcc_s_seh-1.dll not found.
#
# 1. Ensure user account has write permission to C:\Users\absol\Anaconda2\envs\gl-env\lib\site-packages\graphlab
# 2. Run graphlab.get_dependencies() to download and install them.
# 3. Restart Python and import graphlab again.
#
# By running the above function, you agree to the following licenses.
#
# * libstdc++: https://gcc.gnu.org/onlinedocs/libstdc++/manual/license.html
# * xz: http://git.tukaani.org/?p=xz.git;a=blob;f=COPYING

# %%
graphlab.get_dependencies()
# Out:
# By running this function, you agree to the following licenses.
#
# * libstdc++: https://gcc.gnu.org/onlinedocs/libstdc++/manual/license.html
# * xz: http://git.tukaani.org/?p=xz.git;a=blob;f=COPYING
#
# ...
# Extracting xz.
# ...
# Extracting gcc-libs.
# Copying gcc-libs into the installation directory.

# %%
import graphlab

# %% [markdown]
# # Load a Tabular DataSet

# %%
import graphlab

# %%
sf = graphlab.SFrame('people-example.csv')
# Out:
# Finished parsing file C:\Users\absol\mlc\people-example.csv
# Parsing completed. Parsed 7 lines in 0.021547 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file C:\Users\absol\mlc\people-example.csv
# Parsing completed. Parsed 7 lines in 0.024017 secs.

# %% [markdown]
# # SFrame basics

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.head()
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.tail()
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %% [markdown]
# # GraphLab Canvas

# %%
#Take any data structure

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:54848/index.html
# Opening Canvas in default web browser.

# %%
graphlab.canvas.set_target('http://localhost:54848/index.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-ce33ace640ae> in <module>()
# ----> 1 graphlab.canvas.set_target('http://localhost:54848/index.html')
#
# C:\Users\absol\Anaconda2\envs\gl-env\lib\site-packages\graphlab\canvas\utils.pyc in set_target(target, port)
#      84     if not(target in targets):
#      85         raise ValueError('Canvas target \'%s\' is an invalid value. ' \
# ---> 86             'Select from: %s.' % (target, list(targets.keys())))
#      87
#      88     if target in ['browser', 'headless']:
#
# ValueError: Canvas target 'http://localhost:54848/index.html' is an invalid value. Select from: ['headless', 'none', 'ipynb', 'browser'].

# %%
sf.show()

# %%
sf['age'].show(view = 'Categorical')

# %%
sf['age', 'Country'].show(view = 'Categorical')

# %% [markdown]
# # Inspect some columns of a dataset

# %%
sf['Country']
# Out:
# dtype: str
# Rows: 7
# ['United States', 'Canada', 'England', 'USA', 'Poland', 'United States', 'Switzerland']

# %%
sf['country']
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-878ffbee20ef> in <module>()
# ----> 1 sf['country']
#
# C:\Users\absol\Anaconda2\envs\gl-env\lib\site-packages\graphlab\data_structures\sframe.pyc in __getitem__(self, key)
#    3996             return self._row_selector(key)
#    3997         elif type(key) is str:
# -> 3998             return self.select_column(key)
#    3999         elif type(key) is type:
#    4000             return self.select_columns([key])
#
# C:\Users\absol\Anaconda2\envs\gl-env\lib\site-packages\graphlab\data_structures\sframe.pyc in select_column(self, key)
#    3599             raise TypeError("Invalid key type: must be str")
#    3600         with cython_context():
# -> 3601             return SArray(data=[], _proxy=self.__proxy__.select_column(key))
#    3602
#    3603     def select_columns(self, keylist):
#
# ...

# %%
sf['age']
# Out:
# dtype: int
# Rows: 7
# [24L, 23L, 22L, 23L, 23L, 22L, 25L]

# %%
sf['age'].mean()
# Out:
# 23.142857142857146

# %%
sf['age'].max()
# Out:
# 25L

# %% [markdown]
# # Creating a new Column

# %%
sf['Full Name'] = sf['First Name'] + sf['Last Name']

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Full Name	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+---------------+
# | First Name | Last Name |    Country    | age |   Full Name   |
# +------------+-----------+---------------+-----+---------------+
# |    Bob     |   Smith   | United States |  24 |    BobSmith   |
# |   Alice    |  Williams |     Canada    |  23 | AliceWilliams |
# |  Malcolm   |    Jone   |    England    |  22 |  MalcolmJone  |
# |   Felix    |   Brown   |      USA      |  23 |   FelixBrown  |
# |    Alex    |   Cooper  |     Poland    |  23 |   AlexCooper  |
# |    Tod     |  Campbell | United States |  22 |  TodCampbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   DerekWard   |
# +------------+-----------+---------------+-----+---------------+
# [7 rows x 5 columns]

# %%
sf['Full Name'] = sf['First Name'] + ' ' +sf['Last Name']

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Full Name	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |   Full Name    |
# +------------+-----------+---------------+-----+----------------+
# |    Bob     |   Smith   | United States |  24 |   Bob Smith    |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   |      USA      |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
sf['age'] * sf['age']
# Out:
# dtype: int
# Rows: 7
# [576L, 529L, 484L, 529L, 529L, 484L, 625L]

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Full Name	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |   Full Name    |
# +------------+-----------+---------------+-----+----------------+
# |    Bob     |   Smith   | United States |  24 |   Bob Smith    |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   |      USA      |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %% [markdown]
# # Apply function to do advance transformation of our data

# %%
sf['Country']
# Out:
# dtype: str
# Rows: 7
# ['United States', 'Canada', 'England', 'USA', 'Poland', 'United States', 'Switzerland']

# %%
sf['Country'].show()

# %%
def transform_country(country):
    if country == "USA":
        return 'United States'
    else:
        return country

# %%
transform_country('Brasil')
# Out:
# 'Brasil'

# %%
transform_country("USA")
# Out:
# 'United States'

# %%
sf['Country'].apply(transform_country)
# Out:
# dtype: str
# Rows: 7
# ['United States', 'Canada', 'England', 'United States', 'Poland', 'United States', 'Switzerland']

# %%
sf['Country']
# Out:
# dtype: str
# Rows: 7
# ['United States', 'Canada', 'England', 'USA', 'Poland', 'United States', 'Switzerland']

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Full Name	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |   Full Name    |
# +------------+-----------+---------------+-----+----------------+
# |    Bob     |   Smith   | United States |  24 |   Bob Smith    |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   |      USA      |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
sf['Country'] = sf['Country'].apply(transform_country)

# %%
sf['Country'].show(view = "Categorical")

# %%
lola = graphlab.SFrame('Intermediate.csv')
# Out:
# Finished parsing file C:\Users\absol\mlc\Intermediate.csv
# Parsing completed. Parsed 100 lines in 0.201517 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,str,str,str,str,str,str,str,str,str,str,long,str,str,str,str,str,str,str,str,str,str,str,str,long,float,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file C:\Users\absol\mlc\Intermediate.csv
# Parsing completed. Parsed 9805 lines in 0.058025 secs.

# %%
lola.show
# Out:
# <bound method SFrame.show of Columns:
# 	name	str
# 	search_term_01	str
# 	search_term_02	str
# 	search_term_03	str
# 	search_term_04	str
# 	search_term_05	str
# 	search_term_06	str
# 	search_term_07	str
# 	search_term_08	str
# 	search_term_09	str
# 	search_term_10	str
# 	search_term_11	str
# 	search_term_12	str
# 	No. of terms	int
# 	Name1	str
# 	Name2	str
# 	Name3	str
# 	Name4	str
# 	Name5	str
# 	Name6	str
# 	Name7	str
# 	Name8	str
# 	Name9	str
# 	Name10	str
# 	Name11	str
# 	Name12	str
# 	Name	int
# 	per	float
# 	round	int
#
# Rows: 9805
#
# Data:
# +------------------------------+----------------+----------------+----------------+
# |             name             | search_term_01 | search_term_02 | search_term_03 |
# +------------------------------+----------------+----------------+----------------+
# |     Adjustable Lamp Head     |    KITCHEN     |    LIGHTING    |     (null)     |
# |        Accessory Type        |     double     |      wall      |   telescopic   |
# ...

# %%
lola.show()

# %%
lola.show()

# %%
lola['name'].show()
